jpg
#   inflating: /content/intel_dataset/seg_train/seg_train/street/8727.jpg
#   inflating: /content/intel_dataset/seg_train/seg_train/street/874.jpg
#   inflating: /content/intel_dataset/seg_train/seg_train/street/8747.jpg
#   inflating: /content/intel_dataset/seg_train/seg_train/street/8751.jpg
#   inflating: /content/intel_dataset/seg_train/seg_train/street/8754.jpg
#   inflating: /content/intel_dataset/seg_train/seg_train/street/8755.jpg
#   inflating: /content/intel_dataset/seg_train/seg_train/street/8760.jpg
#   inflating: /content/intel_dataset/seg_train/seg_train/street/8761.jpg
#   inflating: /content/intel_dataset/seg_train/seg_train/street/8774.jpg
#   inflating: /content/intel_dataset/seg_train/seg_train/street/8794.jpg
#   inflating: /content/intel_dataset/seg_train/seg_train/street/8818.jpg
#   inflating: /content/intel_dataset/seg_train/seg_train/street/8842.jpg
#   inflating: /content/intel_dataset/seg_train/seg_train/street/8844.jpg
#   inflating: /content/intel_dataset/seg_train/seg_train/street/8848.jpg
#   inflating: /content/intel_dataset/seg_train/seg_train/street/886.jpg
#   inflating: /content/intel_dataset/seg_train/seg_train/street/8864.jpg
#   inflating: /content/intel_dataset/seg_train/seg_train/street/8866.jpg
#   inflating: /content/intel_dataset/seg_train/seg_train/street/8871.jpg
#   inflating: /content/intel_dataset/seg_train/seg_train/street/8876.jpg
#   inflating: /content/intel_dataset/seg_train/seg_train/street/8880.jpg
#   inflating: /content/intel_dataset/seg_train/seg_train/street/8885.jpg
#   inflating: /content/intel_dataset/seg_train/seg_train/street/889.jpg
#   inflating: /content/intel_dataset/seg_train/seg_train/street/8907.jpg
#   inflating: /content/intel_dataset/seg_train/seg_train/street/8919.jpg
#   inflating: /content/intel_dataset/seg_train/seg_train/street/8925.jpg
#   inflating: /content/intel_dataset/seg_train/seg_train/street/8928.jpg
#   inflating: /content/intel_dataset/seg_train/seg_train/street/8931.jpg
#   inflating: /content/intel_dataset/seg_train/seg_train/street/8947.jpg
#   inflating: /content/intel_dataset/seg_train/seg_train/street/8949.jpg
#   inflating: /content/intel_dataset/seg_train/seg_train/street/8958.jpg
#   inflating: /content/intel_dataset/seg_train/seg_train/street/8970.jpg
#   inflating: /content/intel_dataset/seg_train/seg_train/street/8974.jpg
#   inflating: /content/intel_dataset/seg_train/seg_train/street/898.jpg
#   inflating: /content/intel_dataset/seg_train/seg_train/street/8981.jpg
#   inflating: /content/intel_dataset/seg_train/seg_train/street/8995.jpg
#   inflating: /content/intel_dataset/seg_train/seg_train/street/8999.jpg
#   inflating: /content/intel_dataset/seg_train/seg_train/street/9.jpg
#   inflating: /content/intel_dataset/seg_train/seg_train/street/9000.jpg
#   inflating: /content/intel_dataset/seg_train/seg_train/street/9004.jpg
#   inflating: /content/intel_dataset/seg_train/seg_train/street/9009.jpg
#   inflating: /content/intel_dataset/seg_train/seg_train/street/9014.jpg
#   inflating: /content/intel_dataset/seg_train/seg_train/street/9036.jpg
#   inflating: /content/intel_dataset/seg_train/seg_train/street/9043.jpg
#   inflating: /content/intel_dataset/seg_train/seg_train/street/9049.jpg
#   inflating: /content/intel_dataset/seg_train/seg_train/street/9076.jpg
#   inflating: /content/intel_dataset/seg_train/seg_train/street/908.jpg
#   inflating: /content/intel_dataset/seg_train/seg_train/street/9080.jpg
#   inflating: /content/intel_dataset/seg_train/seg_train/street/9087.jpg
#   inflating: /content/intel_dataset/seg_train/seg_train/street/9089.jpg
#   inflating: /content/intel_dataset/seg_train/seg_train/street/9099.jpg
#   inflating: /content/intel_dataset/seg_train/seg_train/street/91.jpg
#   inflating: /content/intel_dataset/seg_train/seg_train/street/9103.jpg
#   inflating: /content/intel_dataset/seg_train/seg_train/street/9108.jpg
#   inflating: /content/intel_dataset/seg_train/seg_train/street/9114.jpg
#   inflating: /content/intel_dataset/seg_train/seg_train/street/9118.jpg
#   inflating: /content/intel_dataset/seg_train/seg_train/street/9124.jpg
#   inflating: /content/intel_dataset/seg_train/seg_train/street/9126.jpg
#   inflating: /content/intel_dataset/seg_train/seg_train/street/9148.jpg
#   inflating: /content/intel_dataset/seg_train/seg_train/street/9158.jpg
#   inflating: /content/intel_dataset/seg_train/seg_train/street/9160.jpg
#   inflating: /content/intel_dataset/seg_train/seg_train/street/9164.jpg
#   inflating: /content/intel_dataset/seg_train/seg_train/street/9167.jpg
#   inflating: /content/intel_dataset/seg_train/seg_train/street/9169.jpg
#   inflating: /content/intel_dataset/seg_train/seg_train/street/9184.jpg
#   inflating: /content/intel_dataset/seg_train/seg_train/street/9188.jpg
#   inflating: /content/intel_dataset/seg_train/seg_train/street/9192.jpg
#   inflating: /content/intel_dataset/seg_train/seg_train/street/9193.jpg
#   inflating: /content/intel_dataset/seg_train/seg_train/street/9224.jpg
#   inflating: /content/intel_dataset/seg_train/seg_train/street/9234.jpg
#   inflating: /content/intel_dataset/seg_train/seg_train/street/9236.jpg
#   inflating: /content/intel_dataset/seg_train/seg_train/street/9271.jpg
#   inflating: /content/intel_dataset/seg_train/seg_train/street/9274.jpg
#   inflating: /content/intel_dataset/seg_train/seg_train/street/9275.jpg
#   inflating: /content/intel_dataset/seg_train/seg_train/street/9278.jpg
#   inflating: /content/intel_dataset/seg_train/seg_train/street/9287.jpg
#   inflating: /content/intel_dataset/seg_train/seg_train/street/9299.jpg
#   inflating: /content/intel_dataset/seg_train/seg_train/street/931.jpg
#   inflating: /content/intel_dataset/seg_train/seg_train/street/9327.jpg
#   inflating: /content/intel_dataset/seg_train/seg_train/street/9342.jpg
#   inflating: /content/intel_dataset/seg_train/seg_train/street/9346.jpg
#   inflating: /content/intel_dataset/seg_train/seg_train/street/9349.jpg
#   inflating: /content/intel_dataset/seg_train/seg_train/street/9350.jpg
#   inflating: /content/intel_dataset/seg_train/seg_train/street/9351.jpg
#   inflating: /content/intel_dataset/seg_train/seg_train/street/9352.jpg
#   inflating: /content/intel_dataset/seg_train/seg_train/street/9356.jpg
#   inflating: /content/intel_dataset/seg_train/seg_train/street/9362.jpg
#   inflating: /content/intel_dataset/seg_train/seg_train/street/937.jpg
#   inflating: /content/intel_dataset/seg_train/seg_train/street/9370.jpg
#   inflating: /content/intel_dataset/seg_train/seg_train/street/9376.jpg
#   inflating: /content/intel_dataset/seg_train/seg_train/street/9378.jpg
#   inflating: /content/intel_dataset/seg_train/seg_train/street/94.jpg
#   inflating: /content/intel_dataset/seg_train/seg_train/street/9407.jpg
#   inflating: /content/intel_dataset/seg_train/seg_train/street/9412.jpg
#   inflating: /content/intel_dataset/seg_train/seg_train/street/9413.jpg
#   inflating: /content/intel_dataset/seg_train/seg_train/street/9417.jpg
#   inflating: /content/intel_dataset/seg_train/seg_train/street/9425.jpg
#   inflating: /content/intel_dataset/seg_train/seg_train/street/9442.jpg
#   inflating: /content/intel_dataset/seg_train/seg_train/street/9447.jpg
#   inflating: /content/intel_dataset/seg_train/seg_train/street/9448.jpg
#   inflating: /content/intel_dataset/seg_train/seg_train/street/945.jpg
#   inflating: /content/intel_dataset/seg_train/seg_train/street/946.jpg
#   inflating: /content/intel_dataset/seg_train/seg_train/street/9468.jpg
#   inflating: /content/intel_dataset/seg_train/seg_train/street/9482.jpg
#   inflating: /content/intel_dataset/seg_train/seg_train/street/9484.jpg
#   inflating: /content/intel_dataset/seg_train/seg_train/street/9489.jpg
#   inflating: /content/intel_dataset/seg_train/seg_train/street/9516.jpg
#   inflating: /content/intel_dataset/seg_train/seg_train/street/9521.jpg
#   inflating: /content/intel_dataset/seg_train/seg_train/street/9530.jpg
#   inflating: /content/intel_dataset/seg_train/seg_train/street/9535.jpg
#   inflating: /content/intel_dataset/seg_train/seg_train/street/9581.jpg
#   inflating: /content/intel_dataset/seg_train/seg_train/street/9595.jpg
#   inflating: /content/intel_dataset/seg_train/seg_train/street/9600.jpg
#   inflating: /content/intel_dataset/seg_train/seg_train/street/9609.jpg
#   inflating: /content/intel_dataset/seg_train/seg_train/street/9649.jpg
#   inflating: /content/intel_dataset/seg_train/seg_train/street/9652.jpg
#   inflating: /content/intel_dataset/seg_train/seg_train/street/9655.jpg
#   inflating: /content/intel_dataset/seg_train/seg_train/street/9662.jpg
#   inflating: /content/intel_dataset/seg_train/seg_train/street/9685.jpg
#   inflating: /content/intel_dataset/seg_train/seg_train/street/9687.jpg
#   inflating: /content/intel_dataset/seg_train/seg_train/street/9690.jpg
#   inflating: /content/intel_dataset/seg_train/seg_train/street/9693.jpg
#   inflating: /content/intel_dataset/seg_train/seg_train/street/970.jpg
#   inflating: /content/intel_dataset/seg_train/seg_train/street/9704.jpg
#   inflating: /content/intel_dataset/seg_train/seg_train/street/9707.jpg
#   inflating: /content/intel_dataset/seg_train/seg_train/street/971.jpg
#   inflating: /content/intel_dataset/seg_train/seg_train/street/9717.jpg
#   inflating: /content/intel_dataset/seg_train/seg_train/street/9720.jpg
#   inflating: /content/intel_dataset/seg_train/seg_train/street/9733.jpg
#   inflating: /content/intel_dataset/seg_train/seg_train/street/9734.jpg
#   inflating: /content/intel_dataset/seg_train/seg_train/street/974.jpg
#   inflating: /content/intel_dataset/seg_train/seg_train/street/9744.jpg
#   inflating: /content/intel_dataset/seg_train/seg_train/street/9749.jpg
#   inflating: /content/intel_dataset/seg_train/seg_train/street/9760.jpg
#   inflating: /content/intel_dataset/seg_train/seg_train/street/9770.jpg
#   inflating: /content/intel_dataset/seg_train/seg_train/street/9798.jpg
#   inflating: /content/intel_dataset/seg_train/seg_train/street/9817.jpg
#   inflating: /content/intel_dataset/seg_train/seg_train/street/9843.jpg
#   inflating: /content/intel_dataset/seg_train/seg_train/street/9846.jpg
#   inflating: /content/intel_dataset/seg_train/seg_train/street/9847.jpg
#   inflating: /content/intel_dataset/seg_train/seg_train/street/9863.jpg
#   inflating: /content/intel_dataset/seg_train/seg_train/street/9867.jpg
#   inflating: /content/intel_dataset/seg_train/seg_train/street/9872.jpg
#   inflating: /content/intel_dataset/seg_train/seg_train/street/9875.jpg
#   inflating: /content/intel_dataset/seg_train/seg_train/street/9878.jpg
#   inflating: /content/intel_dataset/seg_train/seg_train/street/9879.jpg
#   inflating: /content/intel_dataset/seg_train/seg_train/street/9885.jpg
#   inflating: /content/intel_dataset/seg_train/seg_train/street/9891.jpg
#   inflating: /content/intel_dataset/seg_train/seg_train/street/9895.jpg
#   inflating: /content/intel_dataset/seg_train/seg_train/street/9903.jpg
#   inflating: /content/intel_dataset/seg_train/seg_train/street/9911.jpg
#   inflating: /content/intel_dataset/seg_train/seg_train/street/992.jpg
#   inflating: /content/intel_dataset/seg_train/seg_train/street/9926.jpg
#   inflating: /content/intel_dataset/seg_train/seg_train/street/9931.jpg
#   inflating: /content/intel_dataset/seg_train/seg_train/street/9934.jpg
#   inflating: /content/intel_dataset/seg_train/seg_train/street/994.jpg
#   inflating: /content/intel_dataset/seg_train/seg_train/street/9953.jpg
#   inflating: /content/intel_dataset/seg_train/seg_train/street/9959.jpg
#   inflating: /content/intel_dataset/seg_train/seg_train/street/9961.jpg
#   inflating: /content/intel_dataset/seg_train/seg_train/street/9967.jpg
#   inflating: /content/intel_dataset/seg_train/seg_train/street/9978.jpg
#   inflating: /content/intel_dataset/seg_train/seg_train/street/9989.jpg
#   inflating: /content/intel_dataset/seg_train/seg_train/street/999.jpg

# %%
# %%writefile data_loader.py
import torchvision.transforms as transforms
import torchvision.datasets as datasets
from torch.utils.data import DataLoader, random_split


def get_data_loaders(dataset_path, batch_size=32, train_split=0.7, val_split=0.15, test_split=0.15):
    """
    Load the Intel Image Classification dataset and create DataLoaders.

    Parameters:
        dataset_path (str): Path to the dataset (should point to the folder containing class subfolders).
        batch_size (int): Batch size for DataLoaders.
        train_split (float): Fraction of the dataset for training.
        val_split (float): Fraction of the dataset for validation.
        test_split (float): Fraction of the dataset for testing.

    Returns:
        train_loader, val_loader, test_loader (DataLoader): Data loaders for training, validation, and testing.
    """

    # Define transforms for training (data augmentation) and testing/validation (only resizing)
    train_transforms = transforms.Compose([
        transforms.RandomResizedCrop(224),
        transforms.RandomHorizontalFlip(),
        transforms.ToTensor(),
        transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225])
    ])
    test_transforms = transforms.Compose([
        transforms.Resize((224, 224)),
        transforms.ToTensor(),
        transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225])
    ])

    # Load the full dataset using ImageFolder
    full_dataset = datasets.ImageFolder(root=dataset_path, transform=train_transforms)

    # Calculate split sizes
    total_size = len(full_dataset)
    train_size = int(train_split * total_size)
    val_size = int(val_split * total_size)
    test_size = total_size - train_size - val_size

    # Split the dataset
    train_dataset, val_dataset, test_dataset = random_split(full_dataset, [train_size, val_size, test_size])

    # For validation and test sets, apply the test_transforms
    val_dataset.dataset.transform = test_transforms
    test_dataset.dataset.transform = test_transforms

    # Create DataLoaders
    train_loader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True)
    val_loader = DataLoader(val_dataset, batch_size=batch_size, shuffle=False)
    test_loader = DataLoader(test_dataset, batch_size=batch_size, shuffle=False)

    return train_loader, val_loader, test_loader
# Out:
# Writing data_loader.py

# %%
import torch
import torch.nn as nn
import torchvision.models as models
import torchvision.transforms as transforms
from torchvision.datasets import ImageFolder
from torch.utils.data import DataLoader
import torch.optim as optim
import time
import matplotlib.pyplot as plt
import torchvision.datasets as datasets
from tqdm import tqdm  # Make sure to install it with: pip install tqdm
from torch.utils.data import DataLoader, random_split
from sklearn.metrics import accuracy_score, f1_score, confusion_matrix
import seaborn as sns
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
NUM_CLASSES = 6  # Intel Image Classification has 6 categories

# %%
from data_loader import get_data_loaders
DATASET_PATH = "/content/intel_dataset"
train_loader, val_loader, test_loader = get_data_loaders(DATASET_PATH, batch_size=32)

# %%
class ResNet18Model(nn.Module):
    def __init__(self, fine_tune=True):
        super(ResNet18Model, self).__init__()
        self.model = models.resnet18(weights=models.ResNet18_Weights.DEFAULT)  # Load pretrained ResNet-18
        self.model.fc = nn.Linear(self.model.fc.in_features, NUM_CLASSES)  # Modify the FC layer

        if not fine_tune:  # Freeze layers if fine_tune is False
            for param in self.model.parameters():
                param.requires_grad = False
            print(" ResNet-18 loaded with frozen layers.")
        else:
            print(" ResNet-18 loaded with full training.")

    def forward(self, x):
        return self.model(x)

# %%
def train_model(model, criterion, optimizer, num_epochs=25, scheduler=None, device='cuda'):
    train_losses, test_losses, train_accs, test_accs = [], [], [], []

    for epoch in range(num_epochs):
        model.train()
        running_loss, correct, total = 0.0, 0, 0

        start_time = time.time()
        for images, labels in tqdm(train_loader, desc=f"Epoch {epoch+1}/{num_epochs}", leave=False):
            images, labels = images.to(device), labels.to(device)

            optimizer.zero_grad()         # Reset gradients
            outputs = model(images)         # Forward pass
            loss = criterion(outputs, labels)  # Compute loss
            loss.backward()                 # Backward pass
            optimizer.step()                # Update weights

            running_loss += loss.item()
            _, predicted = torch.max(outputs, 1)
            total += labels.size(0)
            correct += (predicted == labels).sum().item()

        train_loss = running_loss / len(train_loader)
        train_acc = 100 * correct / total

        # Evaluate on the test set
        test_loss, test_acc = evaluate_model(model, criterion, device=device)

        # Step the learning rate scheduler if provided
        if scheduler is not None:
            scheduler.step()

        epoch_time = time.time() - start_time

        train_losses.append(train_loss)
        test_losses.append(test_loss)
        train_accs.append(train_acc)
        test_accs.append(test_acc)

        print(f"Epoch {epoch+1}/{num_epochs}: "
              f"Train Loss: {train_loss:.4f}, Train Acc: {train_acc:.2f}% | "
              f"Test Loss: {test_loss:.4f}, Test Acc: {test_acc:.2f}% | "
              f"Time: {epoch_time:.2f}s")

    return train_losses, test_losses, train_accs, test_accs

# %%
def evaluate_model(model, criterion, device='cuda'):
    model.eval()
    test_loss, correct, total = 0.0, 0, 0

    with torch.no_grad():
        for images, labels in test_loader:
            images, labels = images.to(device), labels.to(device)
            outputs = model(images)
            loss = criterion(outputs, labels)
            test_loss += loss.item()
            _, predicted = torch.max(outputs, 1)
            total += labels.size(0)
            correct += (predicted == labels).sum().item()

    test_loss /= len(test_loader)
    test_acc = 100 * correct / total
    return test_loss, test_acc

# %%
def plot_metrics(train_losses, test_losses, train_accs, test_accs, model_name):
    plt.figure(figsize=(12, 5))

    # Plot Loss
    plt.subplot(1, 2, 1)
    plt.plot(train_losses, label='Train Loss')
    plt.plot(test_losses, label='Test Loss')
    plt.title(f'{model_name} Loss')
    plt.xlabel('Epoch')
    plt.ylabel('Loss')
    plt.legend()

    # Plot Accuracy
    plt.subplot(1, 2, 2)
    plt.plot(train_accs, label='Train Accuracy')
    plt.plot(test_accs, label='Test Accuracy')
    plt.title(f'{model_name} Accuracy')
    plt.xlabel('Epoch')
    plt.ylabel('Accuracy (%)')
    plt.legend()

    plt.show()

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
resnet18_model = ResNet18Model(fine_tune=True).to(device)

# Define loss function
criterion = nn.CrossEntropyLoss()

# Define optimizer (e.g., Adam)
optimizer = optim.Adam(resnet18_model.parameters(), lr=0.0001)

# Define a learning rate scheduler (e.g., StepLR)
scheduler = optim.lr_scheduler.StepLR(optimizer, step_size=5, gamma=0.5)

# Train the model (adjust num_epochs as needed)
train_losses, test_losses, train_accs, test_accs = train_model(
    resnet18_model, criterion, optimizer, num_epochs=10, scheduler=scheduler, device=device
)

# Plot training and test metrics
plot_metrics(train_losses, test_losses, train_accs, test_accs, model_name="ResNet-18 (Full Training)")
# Out:
# Downloading: "https://download.pytorch.org/models/resnet18-f37072fd.pth" to /root/.cache/torch/hub/checkpoints/resnet18-f37072fd.pth
# 100%|██████████| 44.7M/44.7M [00:00<00:00, 166MB/s]
#  ResNet-18 loaded with full training.
# Epoch 1/10: Train Loss: 1.0159, Train Acc: 54.66% | Test Loss: 0.9600, Test Acc: 56.94% | Time: 104.35s
# Epoch 2/10: Train Loss: 0.9307, Train Acc: 57.09% | Test Loss: 0.9678, Test Acc: 56.15% | Time: 102.81s
# Epoch 3/10: Train Loss: 0.8684, Train Acc: 60.43% | Test Loss: 1.0610, Test Acc: 46.78% | Time: 100.93s
# Epoch 4/10: Train Loss: 0.6621, Train Acc: 71.56% | Test Loss: 1.3029, Test Acc: 51.52% | Time: 100.27s
# Epoch 5/10: Train Loss: 0.3168, Train Acc: 88.31% | Test Loss: 1.7258, Test Acc: 42.21% | Time: 99.90s
# Epoch 6/10: Train Loss: 0.0989, Train Acc: 97.24% | Test Loss: 2.0330, Test Acc: 49.79% | Time: 101.86s
# Epoch 7/10: Train Loss: 0.0402, Train Acc: 99.16% | Test Loss: 2.1103, Test Acc: 47.14% | Time: 102.42s
# Epoch 8/10: Train Loss: 0.0280, Train Acc: 99.45% | Test Loss: 2.3059, Test Acc: 49.11% | Time: 100.18s
# Epoch 9/10: Train Loss: 0.0218, Train Acc: 99.61% | Test Loss: 2.4085, Test Acc: 48.15% | Time: 102.10s
# Epoch 10/10: Train Loss: 0.0312, Train Acc: 99.17% | Test Loss: 2.4168, Test Acc: 46.40% | Time: 101.64s

# %%
def evaluate_and_analyze(model, test_loader, device='cuda'):
    """
    Evaluate the model on the test set and compute:
      - Test Loss
      - Test Accuracy
      - Weighted F1-Score
      - Confusion Matrix
    """
    model.eval()
    all_preds = []
    all_labels = []
    test_loss = 0.0
    criterion = nn.CrossEntropyLoss()

    with torch.no_grad():
        for images, labels in test_loader:
            images, labels = images.to(device), labels.to(device)
            outputs = model(images)
            loss = criterion(outputs, labels)
            test_loss += loss.item()

            # Get predictions
            _, preds = torch.max(outputs, 1)
            all_preds.extend(preds.cpu().numpy())
            all_labels.extend(labels.cpu().numpy())

    test_loss /= len(test_loader)
    test_accuracy = accuracy_score(all_labels, all_preds)
    test_f1 = f1_score(all_labels, all_preds, average='weighted')
    conf_matrix = confusion_matrix(all_labels, all_preds)

    print(f"Test Loss: {test_loss:.4f}")
    print(f"Test Accuracy: {test_accuracy*100:.2f}%")
    print(f"Test F1 Score: {test_f1:.4f}")

    return test_loss, test_accuracy, test_f1, conf_matrix, all_labels, all_preds

# %%
def plot_confusion_matrix(conf_matrix, class_names):
    """
    Plot the confusion matrix as a heatmap.

    Parameters:
        conf_matrix (array): Confusion matrix from sklearn.metrics.confusion_matrix.
        class_names (list): List of class labels.
    """
    plt.figure(figsize=(8, 6))
    sns.heatmap(conf_matrix, annot=True, fmt="d", cmap='Blues',
                xticklabels=class_names, yticklabels=class_names)
    plt.ylabel('True Label')
    plt.xlabel('Predicted Label')
    plt.title('Confusion Matrix')
    plt.show()

# %%
# Evaluate the model on the test set and compute metrics
test_loss, test_accuracy, test_f1, conf_matrix, true_labels, pred_labels = evaluate_and_analyze(resnet18_model, test_loader, device=device)

# Get class names (adjust based on how you load your dataset)
# For example, if you used ImageFolder, it might be:
class_names = train_loader.dataset.dataset.classes  # or similar depending on your data loader setup

# Plot the confusion matrix as a heatmap
plot_confusion_matrix(conf_matrix, class_names)
# Out:
# Test Loss: 2.4168
# Test Accuracy: 46.40%
# Test F1 Score: 0.4449
